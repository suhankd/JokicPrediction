# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from sklearn.preprocessing import StandardScaler

from processing import processing

# %%
dfs = processing("Data")

scaler = StandardScaler()

all_data = np.concatenate([dfs[f'Data\\{year}'].drop('PtsNextGame', axis=1).to_numpy() for year in range(2021, 2025)], axis=0)
scaler.fit(all_data)
# Out:
# StandardScaler()

# %%
model_CNN = tf.keras.models.load_model("Models/Model_CNN.keras")

model_CNN.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)               │ (None, 16, 64)         │           192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 8, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │        25,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# ...

# %%
X = dfs['Data\\2024'].drop('PtsNextGame', axis = 1).to_numpy()
y = dfs['Data\\2024']['PtsNextGame'].to_numpy()

X = scaler.transform(X)

X = X.reshape((X.shape[0], X.shape[1], 1))


y = y.reshape(y.shape[0], 1)

predictions = model_CNN.predict(X)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[20.075153 ],
#        [13.145417 ],
#        [38.98571  ],
#        [27.809896 ],
#        [28.652935 ],
#        [26.5388   ],
#        [11.800958 ],
#        [18.308868 ],
#        [28.214418 ],
#        [22.315832 ],
#        [20.043034 ],
#        [19.437998 ],
#        [30.712568 ],
#        [65.41104  ],
#        [25.579802 ],
#        [17.342281 ],
#        [23.430597 ],
#        [11.920591 ],
#        [19.580942 ],
#        [17.774126 ],
#        [24.641014 ],
#        [49.141994 ],
#        [26.054607 ],
#        [59.348225 ],
#        [25.537134 ],
#        [32.262577 ],
#        [33.2945   ],
#        [32.45781  ],
#        [15.143922 ],
#        [17.540638 ],
#        [16.876574 ],
#        [20.47343  ],
#        [26.59325  ],
#        [16.63971  ],
#        [24.08446  ],
#        [29.54694  ],
#        [33.175663 ],
#        [25.111029 ],
#        [19.881004 ],
#        [24.301228 ],
#        [46.931274 ],
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plot = plt.figure(figsize=(15,15))
